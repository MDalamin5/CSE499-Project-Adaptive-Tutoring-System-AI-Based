# %%
import pandas as pd

# %%
df = pd.read_csv('Intelligent_Tutoring_Sample_Dataset.csv')
df
# Out:
#     conversation_id                        topic  turn  step     role  \
# 0                 1     Solving Linear Equations     1     1  student
# 1                 1     Solving Linear Equations     2     1   system
# 2                 1     Solving Linear Equations     3     1  student
# 3                 1     Solving Linear Equations     4     1   system
# 4                 1     Solving Linear Equations     5     1  student
# 5                 1     Solving Linear Equations     6     2   system
# 6                 1     Solving Linear Equations     7     2  student
# 7                 1     Solving Linear Equations     8     2   system
# 8                 1     Solving Linear Equations     9     2  student
# 9                 1     Solving Linear Equations    10     3   system
# 10                2  Solving Quadratic Equations     1     1  student
# 11                2  Solving Quadratic Equations     2     1   system
# ...
